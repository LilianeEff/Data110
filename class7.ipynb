# %% [markdown]
# <a href="https://colab.research.google.com/github/LilianeEff/Data110/blob/main/class7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
penguins = sns.load_dataset("penguins")

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
plt.scatter(penguins['bill_length_mm'], penguins['bill_depth_mm'])

# %%
plt.scatter(penguins['bill_length_mm'], penguins['flipper_length_mm'])

# %%
plt.scatter(penguins['bill_length_mm'], penguins['body_mass_g'])

# %%
plt.scatter(penguins['flipper_length_mm'], penguins['bill_length_mm'])

# %%
plt.scatter(penguins['flipper_length_mm'], penguins['body_mass_g'])

# %%
plt.scatter(penguins['flipper_length_mm'], penguins['bill_depth_mm'])

# %%
plt.scatter(penguins['body_mass_g'], penguins['bill_length_mm'])

# %%
plt.scatter(penguins['body_mass_g'], penguins['bill_depth_mm'])

# %%
sns.pairplot(penguins)

# %%
sns.pairplot(penguins, hue='species')

# %%
sns.pairplot(penguins, hue='island')

# %%
sns.pairplot(penguins, hue='sex')

# %%
sns.pairplot(penguins, hue='species', palette='Set2')

# %%
plt.bar(penguins['species'], penguins['body_mass_g'])
# Out:
# <BarContainer object of 344 artists>

# %%
species_max=penguins.groupby('species')['body_mass_g'].max()  #arrange penguins by species(grouped by) and finding the mean of their body mass.
print(species_max.index)
# Out:
# Index(['Adelie', 'Chinstrap', 'Gentoo'], dtype='object', name='species')

# %%
print(species_max.values)
# Out:
# [4775. 4800. 6300.]

# %%
species_mean=penguins.groupby('species')['body_mass_g'].mean()

plt.bar(species_mean.index, species_mean.values)
# Out:
# <BarContainer object of 3 artists>

# %%
print(species_mean.index)
print(species_mean.values)
# Out:
# Index(['Adelie', 'Chinstrap', 'Gentoo'], dtype='object', name='species')
# [3700.66225166 3733.08823529 5076.01626016]

# %%
penguins.groupby('species')['body_mass_g'].count()
# Out:
# species
# Adelie       151
# Chinstrap     68
# Gentoo       123
# Name: body_mass_g, dtype: int64

# %%
from IPython.display import display
display(penguins) # Displays the entire DataFrame
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
species_count=penguins['species'].value_counts()
print(species_count)    #find out where the missing values are according to the species in the body mass column.  There were two
#missing values out of 344 penguins, one belonging to Gentoo and the other to Adelie.
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguins['volume'] = penguins['bill_length_mm'] * penguins['bill_depth_mm'] * penguins['flipper_length_mm']

# Then, you can group by species and count:
volume_counts = penguins.groupby('species')['volume'].count()
print(volume_counts)
# Out:
# species
# Adelie       151
# Chinstrap     68
# Gentoo       123
# Name: volume, dtype: int64

# %%
sns.barplot(x='species', y='body_mass_g', data=penguins, hue='sex')
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x='species', y='body_mass_g', hue='island', data=penguins)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
species_island_counts = penguins.groupby('island')['species'].value_counts()
print(species_island_counts)
# Out:
# island     species
# Biscoe     Gentoo       124
#            Adelie        44
# Dream      Chinstrap     68
#            Adelie        56
# Torgersen  Adelie        52
# Name: count, dtype: int64

# %%
species_island_counts = penguins.groupby('island')['species'].value_counts().unstack()

species_island_counts.plot(kind='bar', stacked=False)
plt.title('Penguin Species Distribution by Island')
plt.xlabel('Island')
plt.ylabel('Number of Penguins')
plt.legend(title='Species')
plt.show()

# %%
sns.barplot(x='island', y='body_mass_g', hue='species', data=penguins)
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
sns.barplot(x='island', y='body_mass_g', hue='sex', data=penguins)
# Out:
# <Axes: xlabel='island', ylabel='body_mass_g'>

# %%
sns.barplot(x='species', y='body_mass_g', hue='island', data=penguins)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x='sex', y='body_mass_g', hue='species', data=penguins)
# Out:
# <Axes: xlabel='sex', ylabel='body_mass_g'>

# %%
sns.barplot(x='sex', y='body_mass_g', hue='island', data=penguins)
# Out:
# <Axes: xlabel='sex', ylabel='body_mass_g'>

# %%
labels= ['a', 'b', 'c']
sizes= [50,25,25]
colors= ['teal', 'blue', 'pink']
plt.pie(sizes, labels=labels, autopct='%1.2f%%', colors=colors)
plt.show()

# %%
species_count= penguins['species'].value_counts()
plt.pie(species_count.values, labels=species_count.index, autopct='%1.2f%%')
plt.show()
print(species_count)
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
species_count= penguins['species'].value_counts()
explodes= [0, 0.1, 0]
plt.pie(species_count.values, labels=species_count.index, autopct='%1.2f%%', hatch=['**0', 'o0', '-'], explode=explodes)
plt.show()
print(species_count)
# Out:
# <ipython-input-81-0b171881c931>:3: MatplotlibDeprecationWarning: hatch must consist of a string of "*+-./OX\ox|" or None, but found the following invalid values "0". Passing invalid values is deprecated since 3.4 and will become an error in 3.8.
#   plt.pie(species_count.values, labels=species_count.index, autopct='%1.2f%%', hatch=['**0', 'o0', '-'], explode=explodes)
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
from re import X
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
penguins.dropna(inplace=True)
features= ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']
X= penguins[features]
scaler= StandardScaler()
X_scaled= scaler.fit_transform(X)
kmeans= KMeans(n_clusters=3, random_state=42)
penguins['cluster']= kmeans.fit_predict(X_scaled)
kmeans.fit(X_scaled)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='bill_length_mm', y='bill_depth_mm', hue='cluster', data=penguins)
plt.title('Penguin Clusters')
plt.xlabel('Bill Length (mm)')
plt.ylabel('Bill Depth (mm)')
plt.show()
