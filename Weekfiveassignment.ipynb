# %% [markdown]
# <a href="https://colab.research.google.com/github/LilianeEff/Data110/blob/main/Weekfiveassignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Understanding the dataset
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt


titanic = sns.load_dataset('titanic')
titanic.head() # the first five values of the dataset.
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic # The entire dataset. It tells us that there are 891 rows and 15 columns.
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
print(titanic['survived'].value_counts()) #how many people died, and how many survived.
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
print(titanic['sex'].value_counts()) #how many people were male and how many were female.
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
print(titanic['class'].value_counts()) #how many people were in first class, second class, and third class.
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
print(titanic.groupby('sex')['survived'].value_counts()) # how many survivors and non-survivors there were according to their gender.
# Out:
# sex     survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: count, dtype: int64

# %%
titanic.describe(include='all') # summary statistics of passengers who boarded the ship. It includes the means, standard deviations, the minimums,
#maximums, and quartiles of the quantitative values. The missing data are for the categorical values.
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %% [markdown]
# 1. The titanic dataset contains the list of passengers who boarded the doomed ship. It includes their genders, ages, what class they boarded, how much they paid, where they embarked from, and whether they were rescued after the ship sank. From it we surmise that there were 891 passengers on board total. There were 577 males, and 314 females. The first class had 216 people, the second 184, and the third 491. Of the 891 passengers, 549 died(81 females and 468 males), and 342 survived(233females and 109 males).

# %%
#2: Fare Distribution
sns.histplot(titanic['fare'], kde=True) #how many tickets were purchased at what prices.
plt.title('Fare Distribution')
plt.xlabel('Fare')
plt.ylabel('Count')
plt.show()

# %%
sns.kdeplot(titanic['fare'], fill=True) #how many tickets were purchased at what prices with a kde plot.
plt.title('Fare Distribution')
plt.show()

# %%
sns.boxplot(x='class', y='fare', data=titanic) #boxplot of the distribution of fares paid by passengers of each class.
plt.title('Fare Distribution by Class')
plt.xlabel('Class')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# The histograms and boxplot tells us that although there were more tickets bought at cheaper prices, the outliers represent those tickets that were bought at a higher price, suggesting that those belonged to  passengers in first class. It is possible that those high-rollers(high tickets spenders) were also treated with the best accomodations, like getting to the first lifeboats.

# %%
#3: Fare and survival rates
plt.figure(figsize=(10, 6))
sns.kdeplot(data=titanic, x='fare', hue='survived', fill=True)
plt.title('Fare Distribution by Survival')
plt.xlabel('Fare')
plt.ylabel('Density')
plt.show()  #kde plot of the number of people who survived according to their socioeconomic status.

# %% [markdown]
# As we can see, most people who did not survive are those whose tickets cost between 0-100, with some outliers going into the 250's. This suggest that passengers in the third class saw the most fatalities, while those in different classes fared better. The classes were clearly divided, and some were favored over others. This does not come as any surprise since it is clear that those who paid more were better accomodated, and even got rescued faster.

# %%
#4: Passengers' class, fare, and survival.
plt.figure(figsize=(10, 6))
sns.histplot(data=titanic, x='fare', hue='pclass')
plt.title('Fare Distribution by Passenger Class')
plt.xlabel('Fare')
plt.ylabel('Count')
plt.show()
#histogram of passengers' class.

# %%
sns.kdeplot(data=titanic, x='fare', hue='pclass', fill=True)
plt.title('Fare Distribution by Passenger Class')
plt.xlabel('Fare')
plt.ylabel('Density')
plt.show()
#kde plot of passengers' class.

# %%
survived = titanic.groupby('pclass')['survived'].value_counts()
print(survived) # the number of people who survived based on their passenger class.
plt.figure(figsize=(8,5))
sns.barplot(x=survived.index.get_level_values(0), y=survived.values, hue=survived.index.get_level_values(1))
plt.title('Count of People Who Survived Based on Their Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.show()  #this graph represents the count of people who survived based on their passenger class.
# Out:
# pclass  survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.kdeplot(data=titanic, x='pclass', hue='survived', fill=True)
plt.title('Class Distribution by Survival')
plt.xlabel('Class')
plt.ylabel('Density')
plt.show()
#kde plot of passengers' class and their survival.

# %% [markdown]
# These graphs show us that even though the larger group of passengers were in the third class, it was the ones in first class who survived the most:136 total, with third class following at 119, and second, which had the least amount of passengers, at 87.  The reason why there are more survivors in the third class compared to the second has to do with the higher number of passengers who were in third class. it is possible that third class passengers were overlooked or when it came time to rescue them, there were no more lifeboats.

# %%
#5. Age of survivors and non-survivors
plt.figure(figsize=(10, 6))
sns.kdeplot(data=titanic, x='age', hue='survived', fill=True)
plt.title('Age Distribution by Survival')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show() #kde plot comparing age distribution among survivors and non-survivors.

# %% [markdown]
# This graph shows us that the majority of non-survivors were between the ages of 20-30 years old, while children had the highest survival rate, followed by older adults. This suggests that children and the elderly were prioritized in the lifeboats. Usually people(in those days mostly men) of 'working age' would set out to do tasks that facilitates saving people when a tragedy strikes; making sure that women, children, and the elderly are taken care of before taking care of themselves.

# %%
#5: Pyramid histograms for age survival by sex
def create_population_pyramid(data, title):
    """Creates a vertical population pyramid with age and sex, split by survival status."""

    survived = data[data['survived'] == 1]
    not_survived = data[data['survived'] == 0]

    fig, axes = plt.subplots(ncols=2, sharey=True, figsize=(10, 6))

    # Survived
    sns.histplot(x=survived[survived['sex'] == 'male']['age'],
                 ax=axes[0], color='skyblue', label='Male', bins=20, kde=True)
    sns.histplot(x=survived[survived['sex'] == 'female']['age'],
                 ax=axes[0], color='lightcoral', label='Female', bins=20, kde=True)
    axes[0].set_title('Survived')
    axes[0].set_xlabel('Age')
    axes[0].legend()

    # Not Survived
    sns.histplot(x=not_survived[not_survived['sex'] == 'male']['age'],
                 ax=axes[1], color='skyblue', label='Male', bins=20, kde=True)
    sns.histplot(x=not_survived[not_survived['sex'] == 'female']['age'],
                 ax=axes[1], color='lightcoral', label='Female', bins=20, kde=True)
    axes[1].set_title('Not Survived')
    axes[1].set_xlabel('Age')
    axes[1].legend()

    fig.suptitle(title, fontsize=14)
    plt.tight_layout()
    plt.show()

create_population_pyramid(titanic, 'Titanic Passengers: Age and Sex by Survival')

# %%
females_over_50 = titanic[(titanic['sex'] == 'female') & (titanic['age'] > 50)]
num_females_over_50 = len(females_over_50)
print(f"Number of females over 50: {num_females_over_50}") #how many women were over 50
# Out:
# Number of females over 50: 17

# %%
females_survived_over_50 = titanic[(titanic['sex'] == 'female') & (titanic['age'] > 50) & (titanic['survived'] == 1)]
num_females_survived_over_50 = len(females_survived_over_50)
print(f"Number of females who survived and were over 50: {num_females_survived_over_50}") # how many women over 50 survived
# Out:
# Number of females who survived and were over 50: 16

# %% [markdown]
# The histograms suggest that the majority of survivors were children and females. The pyramids support the conclusion that women and children were given priority in the rescue. Above we have the number of females over 50 and even though there were only 17 of them, 16 of them survived. Elderly women were given the most priority rescue.

# %%
#7: Bar graph, line plot, and scatterplot

# 1. Bar Graph: Survival Rate by Passenger Class
survival_rates_by_class = titanic.groupby('pclass')['survived'].mean()
plt.figure(figsize=(8, 5))
sns.barplot(x=survival_rates_by_class.index, y=survival_rates_by_class.values)
plt.title('Survival Rate by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')
plt.show()

# 2. Line Plot: Average Fare by Age
average_fare_by_age = titanic.groupby('age')['fare'].mean()
plt.figure(figsize=(10, 6))
sns.lineplot(x=average_fare_by_age.index, y=average_fare_by_age.values)
plt.title('Average Fare by Age')
plt.xlabel('Age')
plt.ylabel('Average Fare')
plt.show()

# 3. Scatter Plot: Age vs. Fare, Colored by Survival
plt.figure(figsize=(10, 6))
sns.scatterplot(data=titanic, x='age', y='fare', hue='survived')
plt.title('Age vs. Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# These three graphs confirm the findings we did earlier in this assignment. In the bar graph, we are told that the highest number of people who survived were in first class, the second being second, and third last, which makes sense according to their priority. The line plot gives you the average fare by age, denoting that the majority of tickets were held by infants, then people in their mid-thirties, then those in their late 50's, and finally those in their mid-sixties. The scatterplot tells you that children under 10, some people in their 20's, those in their 40's to their 60's had the highest number of survivors, with one outlier in their 80's and a select few in their mid-thirties(who are also outliers in that they paid the highest fares, which would explain why those passengers survived, given their VIP status).
#
# **Conclusion**: To survive the Titanic, one needed to have money, which would afford them a higher passenger class, and first priority if something goes wrong. In addition to that, women and children were also given priority since they had to be protected according to the laws of chivalry.
