# %% [markdown]
# <a href="https://colab.research.google.com/github/LilianeEff/Data110/blob/main/Data110_LilianeEffoudou_week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
url= 'https://raw.githubusercontent.com/LilianeEff/Data110/refs/heads/main/Dataset/crime.csv'
df =  pd.read_csv(url)

df.head()
# Out:
#                offense  Offenses per 100000 people(2023)  \
# 0   Aggravated assault                             264.1
# 1             Burglary                             250.7
# 2              Larceny                            1324.2
# 3  Motor vehicle theft                             318.7
# 4               Murder                               5.7
#
#    Change in offenses per 100000 people (2022-2023)
# 0                                              -3.3
# 1                                              -8.1
# 2                                              -4.9
# 3                                              12.0
# 4                                             -12.0

# %%
#Task1: Basic bar chart for crime rates in 2023
plt.bar(df['offense'], df['Offenses per 100000 people(2023)'], color= 'red')
plt.xlabel('Offense')
plt.xticks(fontsize=6)
plt.ylabel('Offenses per 100000 people(2023)')
plt.title('Offenses rate per 100000 people(2023)')
plt.grid(True)
plt.show()

# %%
#Task 2: Change in crime rates(2022-2023) with unique colors
colors = ['red', 'green', 'blue', 'purple', 'orange', 'brown']
plt.barh(df['offense'], df['Change in offenses per 100000 people (2022-2023)'], color= colors)
plt.xlabel('Change in offenses per 100000 people (2022-2023)')
plt.ylabel('Offense')
plt.title('Change in offenses per 100000 people (2022-2023)')
plt.show()

# %% [markdown]
# 1. Why does this bar graph make more sense than Task 1's bar graph?
#
#   The first graph lists the data for the crimes committed during the year 2023, whereas the second graph gives you a clear idea of how high or low those crimes have occurred as a comparison between two years. There is more information in the second graph since it is a comparison and gives us the percentage value of the offenses.

# %%
#2. Improve the clarity of your bar graph:

# %%
#Task 2: Change in crime rates(2022-2023) with unique colors
colors = ['red', 'yellow', 'maroon', 'turquoise', 'orange', 'brown']
plt.bar(df['offense'], df['Change in offenses per 100000 people (2022-2023)'], color= colors)
plt.xlabel('Offenses')
plt.ylabel('Percentage change in offenses per 100000 people (2022-2023)')
plt.xticks(fontsize=6, rotation=45)
plt.title('Percentage of change in offenses between 2022 and 2023')
plt.grid(True)
plt.show()

# %%
#Task 2: Change in crime rates(2022-2023) with unique colors
colors = ['violet', 'red', 'maroon', 'turquoise', 'orange', 'teal']
plt.barh(df['offense'], df['Change in offenses per 100000 people (2022-2023)'], color= colors)
plt.xlabel('Change in offenses per 100000 people(2022-2023)')
plt.ylabel('Offenses')
plt.xticks(fontsize=6)
plt.title('Data Showing how much lower crime was in 2023 compared to 2022')
plt.grid(which='major', linewidth=0.5, linestyle='-')
plt.grid(which='minor', linestyle='-')
plt.minorticks_on()
plt.show()

# %%
#Task 2: Change in crime rates(2022-2023) with unique colors
colors = ['violet', 'red', 'maroon', 'turquoise', 'orange', 'teal']
plt.barh(df['offense'], df['Change in offenses per 100000 people (2022-2023)'], color= colors)
plt.xlabel('Change in offense per 100000 people (2022-2023)')
plt.ylabel('Offenses')
plt.xticks(fontsize=6)
plt.title('Data Showing how much lower crime was in 2023 compared to 2022')

plt.show()

# %%
#Optional task: combined bar chart for crime rates in 2022 and 2023
df['Offenses per 100000 people(2022)'] = df['Offenses per 100000 people(2023)'] / (1 + df['Change in offenses per 100000 people (2022-2023)'] / 100)

print(df)
# Out:
#                     offense  Offenses per 100000 people(2023)  \
# 0        Aggravated assault                             264.1
# 1                  Burglary                             250.7
# 2                   Larceny                            1324.2
# 3       Motor vehicle theft                             318.7
# 4                    Murder                               5.7
# 5  Rape(revised definition)                              38.0
# 6                   Robbery                              66.5
#
#    Change in offenses per 100000 people (2022-2023)  \
# 0                                              -3.3
# 1                                              -8.1
# 2                                              -4.9
# 3                                              12.0
# 4                                             -12.0
# 5                                              -9.8
# 6                                              -0.8
#
#    Offenses per 100000 people(2022)
# ...
